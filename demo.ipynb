# %%
import torch
import sys
sys.path.append('./apollo')
from transformers import AutoModelForCausalLM
from apollo.mm_utils import (
    KeywordsStoppingCriteria,
    tokenizer_mm_token,
    ApolloMMLoader
)
from apollo.conversations import conv_templates, SeparatorStyle
from apollo.constants import X_TOKEN, X_TOKEN_INDEX

# Parameters
version = "qwen_2"
model_path = "/root/autodl-tmp/Apollo-LMMs-Apollo-7B-t32"

video_path = "904_1737365120.mp4"
question = "Describe this video in detail"
temperature = 0.4
top_p = 0.7
max_output_tokens = 256

device = "cuda" if torch.cuda.is_available() else "cpu"
attn_implementation = "sdpa" if torch.__version__ > "2.1.2" else "eager"

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    trust_remote_code=True,
    low_cpu_mem_usage=True,
    attn_implementation=attn_implementation
).to(device=device, dtype=torch.bfloat16)

# 在包装前保存必要的属性
tokenizer = model.tokenizer
vision_processors = model.vision_tower.vision_processor
config = model.config

max_length = config.llm_cfg['model_max_length']
num_repeat_token = config.mm_connector_cfg['num_output_tokens']
mm_use_im_start_end = config.use_mm_start_end

frames_per_clip = 4
clip_duration = getattr(config, 'clip_duration')

mm_processor = ApolloMMLoader(
    vision_processors,
    clip_duration,
    frames_per_clip,
    clip_sampling_ratio=0.65,
    model_max_length=config.model_max_length,
    device=device,
    num_repeat_token=num_repeat_token
)

model.eval()

mm_data, replace_string = mm_processor.load_video(video_path)
message = replace_string + "\n\n" + question

conv = conv_templates[version].copy()
conv.append_message(conv.roles[0], message)
conv.append_message(conv.roles[1], None)
prompt = conv.get_prompt()

input_ids = tokenizer_mm_token(prompt, tokenizer, return_tensors="pt").unsqueeze(0).to(device)

pad_token_ids = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else tokenizer.eos_token_id
stop_str = conv.sep if conv.sep_style != SeparatorStyle.TWO else conv.sep2
keywords = [stop_str]
stopping_criteria = KeywordsStoppingCriteria(keywords, tokenizer, input_ids)

with torch.inference_mode():
    output_ids = model.generate(  # 如果使用了DataParallel，需要通过module访问原始模型
        input_ids,
        vision_input=[mm_data],
        data_types=['video'],
        do_sample=(temperature > 0),
        temperature=temperature,
        max_new_tokens=max_output_tokens,
        top_p=top_p,
        use_cache=True,
        num_beams=1,
        stopping_criteria=[stopping_criteria]
    )

pred = tokenizer.batch_decode(output_ids, skip_special_tokens=True)[0].strip()
print(pred)
# Out:
# Using 2 GPUs!
# loading:  /root/autodl-tmp/Apollo-LMMs-Apollo-7B-t32/vision_tower/siglip-so400m-patch14-384
# loading:  /root/autodl-tmp/Apollo-LMMs-Apollo-7B-t32/vision_tower/internvideo2
# /root/miniconda3/lib/python3.12/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# You are using a model of type mm_connector to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Using 2 GPUs!
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[1], line 82
#      79 stopping_criteria = KeywordsStoppingCriteria(keywords, tokenizer, input_ids)
#      81 with torch.inference_mode():
# ---> 82     output_ids = model.module.generate(  # 如果使用了DataParallel，需要通过module访问原始模型
#      83         input_ids,
#      84         vision_input=[mm_data],
#      85         data_types=['video'],
#      86         do_sample=(temperature > 0),
#      87         temperature=temperature,
#      88         max_new_tokens=max_output_tokens,
#      89         top_p=top_p,
#      90         use_cache=True,
#      91         num_beams=1,
#      92         stopping_criteria=[stopping_criteria]
#      93     ) if torch.cuda.device_count() > 1 else model.generate(
#      94         input_ids,
#      95         vision_input=[mm_data],
#      96         data_types=['video'],
#      97         do_sample=(temperature > 0),
#      98         temperature=temperature,
#      99         max_new_tokens=max_output_tokens,
#     100         top_p=top_p,
#     101         use_cache=True,
#     102         num_beams=1,
#     103         stopping_criteria=[stopping_criteria]
#     104     )
#     106 pred = tokenizer.batch_decode(output_ids, skip_special_tokens=True)[0].strip()
#     107 print(pred)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.cache/huggingface/modules/transformers_modules/Apollo-LMMs-Apollo-7B-t32/modeling_apollo.py:152, in ApolloForCausalLM.generate(self, inputs, vision_input, data_types, **kwargs)
#     149     raise NotImplementedError("`inputs_embeds` is not supported")
#     151 if vision_input is not None:
# --> 152     (inputs, position_ids, attention_mask, _, inputs_embeds, _) = self.prepare_inputs_labels_for_multimodal(
#     153         inputs, position_ids, attention_mask, None, None, vision_input, data_types=data_types)
#     154 else:
#     155     inputs_embeds = self.embed_tokens(inputs)
#
# File ~/.cache/huggingface/modules/transformers_modules/Apollo-LMMs-Apollo-7B-t32/modeling_apollo.py:308, in ApolloForCausalLM.prepare_inputs_labels_for_multimodal(self, input_ids, position_ids, attention_mask, past_key_values, labels, vision_input, data_types)
#     295 '''
#     296     vision_input is a list of tuples, and data_type is a list of strings:
#     297     data_type = ['image', 'video', 'video'..., 'text']
#    (...)
#     305     -> video encoders typlically expect (C,T,H,W), images expect (C,H,W).
#     306 '''
#     307 # ====================================================================================================
# --> 308 merged_mm_features = self.encode_mm_minibatch(vision_input)
#     310 if not getattr(self.config, "tune_language_model", True) and getattr(self.config, "use_mm_start_end", False):
#     311     raise NotImplementedError
#
# File ~/.cache/huggingface/modules/transformers_modules/Apollo-LMMs-Apollo-7B-t32/modeling_apollo.py:253, in ApolloForCausalLM.encode_mm_minibatch(self, x)
#     251 features = []
#     252 for xx in swapped_x:
# --> 253     xx = self._encode_mm(xx)
#     254     features.append(xx)
#     255 x = torch.cat(features, dim=0)
#
# File ~/.cache/huggingface/modules/transformers_modules/Apollo-LMMs-Apollo-7B-t32/modeling_apollo.py:239, in ApolloForCausalLM._encode_mm(self, x)
#     238 def _encode_mm(self, x):
# --> 239     x = self.get_vision_tower()(x)
#     240     x = self.mm_connector(x)
#     241     return x
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/Apollo-LMMs-Apollo-7B-t32/vision_tower.py:505, in ApolloVisionTower.forward(self, x)
#     503 for x_s, vision_tower_name in zip(x, self.vision_towers):
#     504     vision_tower = getattr(self, vision_tower_name)
# --> 505     features = vision_tower._forward(x_s, out_T=self.T)
#     507     if len(features.shape) != len(self.token_output_shape) + 2:
#     508         features = features.unsqueeze(1)
#
# File ~/.cache/huggingface/modules/transformers_modules/Apollo-LMMs-Apollo-7B-t32/vision_tower.py:369, in VisionTower._forward(self, images, out_T)
#     366     original_shape = images.shape
#     367     images = images.view(-1, *original_shape[2:])
# --> 369 image_features = self.vision_tower_forward(images.to(device=self.device, dtype=self.dtype))
#     370 image_features = self.feature_select(image_features).to(images.dtype)
#     371 # Reshape back to (B, T, ...) if necessary
#
# File ~/.cache/huggingface/modules/transformers_modules/Apollo-LMMs-Apollo-7B-t32/vision_tower.py:350, in VisionTower.vision_tower_forward(self, image)
#     349 def vision_tower_forward(self, image):
# --> 350     image_feature = self.vision_tower(image, output_hidden_states=True)
#     351     return image_feature
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/siglip/modeling_siglip.py:957, in SiglipVisionModel.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict)
#     933 r"""
#     934 Returns:
#     935
#    (...)
#     953 >>> pooled_output = outputs.pooler_output  # pooled features
#     954 ```"""
#     955 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 957 return self.vision_model(
#     958     pixel_values=pixel_values,
#     959     output_attentions=output_attentions,
#     960     output_hidden_states=output_hidden_states,
#     961     return_dict=return_dict,
#     962 )
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/siglip/modeling_siglip.py:858, in SiglipVisionTransformer.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict)
#     854 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     856 hidden_states = self.embeddings(pixel_values)
# --> 858 encoder_outputs = self.encoder(
#     859     inputs_embeds=hidden_states,
#     860     output_attentions=output_attentions,
#     861     output_hidden_states=output_hidden_states,
#     862     return_dict=return_dict,
#     863 )
#     865 last_hidden_state = encoder_outputs[0]
#     866 last_hidden_state = self.post_layernorm(last_hidden_state)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/siglip/modeling_siglip.py:671, in SiglipEncoder.forward(self, inputs_embeds, attention_mask, output_attentions, output_hidden_states, return_dict)
#     664     layer_outputs = self._gradient_checkpointing_func(
#     665         encoder_layer.__call__,
#     666         hidden_states,
#     667         attention_mask,
#     668         output_attentions,
#     669     )
#     670 else:
# --> 671     layer_outputs = encoder_layer(
#     672         hidden_states,
#     673         attention_mask,
#     674         output_attentions=output_attentions,
#     675     )
#     677 hidden_states = layer_outputs[0]
#     679 if output_attentions:
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/siglip/modeling_siglip.py:431, in SiglipEncoderLayer.forward(self, hidden_states, attention_mask, output_attentions)
#     428 residual = hidden_states
#     430 hidden_states = self.layer_norm1(hidden_states)
# --> 431 hidden_states, attn_weights = self.self_attn(
#     432     hidden_states=hidden_states,
#     433     attention_mask=attention_mask,
#     434     output_attentions=output_attentions,
#     435 )
#     436 hidden_states = residual + hidden_states
#     438 residual = hidden_states
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/siglip/modeling_siglip.py:367, in SiglipAttention.forward(self, hidden_states, attention_mask, output_attentions)
#     364     attn_weights = attn_weights + attention_mask
#     366 # upcast attention to fp32
# --> 367 attn_weights = nn.functional.softmax(attn_weights, dim=-1, dtype=torch.float32).to(query_states.dtype)
#     368 attn_weights = nn.functional.dropout(attn_weights, p=self.dropout, training=self.training)
#     369 attn_output = torch.matmul(attn_weights, value_states)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/functional.py:1887, in softmax(input, dim, _stacklevel, dtype)
#    1885     ret = input.softmax(dim)
#    1886 else:
# -> 1887     ret = input.softmax(dim, dtype=dtype)
#    1888 return ret
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.14 GiB. GPU
